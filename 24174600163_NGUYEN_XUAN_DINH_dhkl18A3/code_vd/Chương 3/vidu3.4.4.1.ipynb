# %%
import numpy as np 
arr1 = np.array([0,1,2]) 
arr2 = np.array([5,5,5]) 
arr1 + arr2
# Out:
# array([5, 6, 7])

# %% [markdown]
# VD3.4.2.2

# %%
import numpy as np 
arr1 = np.array([0,1,2]) 
arr1 + 5
# Out:
# array([5, 6, 7])

# %% [markdown]
# VD3.4.4.3

# %%
import numpy as np 
arr = np.array([0,1,2]) 
arr
# Out:
# array([0, 1, 2])

# %%
M=np.ones((3,3)) 
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
arr + M
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])
