# %%
import numpy as np 
arr1=np.random.rand(5) 
arr1
# Out:
# array([0.63175294, 0.63486895, 0.28005421, 0.3044039 , 0.11871002])

# %%
arr2=np.random.rand(5) 
arr2
# Out:
# array([0.74185452, 0.33223735, 0.55268931, 0.78800975, 0.10575034])

# %%
arr_maximum=np.maximum(arr1,arr2) 
print("Mảng kết quả là:",arr_maximum)
# Out:
# Mảng kết quả là: [0.74185452 0.63486895 0.55268931 0.78800975 0.11871002]
