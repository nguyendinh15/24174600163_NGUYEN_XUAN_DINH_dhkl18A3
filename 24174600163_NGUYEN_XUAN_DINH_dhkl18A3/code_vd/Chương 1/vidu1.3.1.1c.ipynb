# %%
class Dog:
    __DogCount = 0
    def __init__(self, name: str, size: str, age: int):
        self.__name = name 
        self.__age = age
        Dog.__DogCount += 1

    def __display(self): 
        print(f"Name: {self.__name}, Age: {self.__age}")
    def get_name(self):
        return self.__name
    
d = Dog("Bull", "large", 2)
d._Dog__display()
# Out:
# Name: Bull, Age: 2
