# %%
import numpy as np
import pandas as pd

# 1. None khiến dtype chuyển thành "object"
arr_none = np.array([1, 2, None, 3])
print("1. Mảng có None (dtype=object):")
print(arr_none)
# Out:
# 1. Mảng có None (dtype=object):
# [1 2 None 3]

# %%
type(arr_none)
# Out:
# numpy.ndarray

# %%
for dtype, in ['object','int']:
    print( "dtype=" ,dtype)
    # %timeit nonlocalp.arange(1E6,dtype=dtype).sum()
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for dtype, in ['object','int']:
#       2     print( "atype=" ,dtype)
#       3     get_ipython().run_line_magic('timeit', 'nonlocalp.arange(1E6,dtype=dtype).sum()')
#
# ValueError: too many values to unpack (expected 1)
