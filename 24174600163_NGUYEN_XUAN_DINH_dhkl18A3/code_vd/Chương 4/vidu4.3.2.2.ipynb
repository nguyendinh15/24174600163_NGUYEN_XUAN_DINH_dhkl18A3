# %%
import pandas as pd 
population_dict = {'Hà Nội':8330830, 
                'Quảng Ninh':1358085, 
                'Nam Định': 1836270, 
                'Đà Nẵng':1195490, 
                'TP.Hồ Chí Minh':9411805} 
population = pd.Series(population_dict, name = "Dan so tinh/thanh pho: ") 
print(population)
# Out:
# Hà Nội            8330830
# Quảng Ninh        1358085
# Nam Định          1836270
# Đà Nẵng           1195490
# TP.Hồ Chí Minh    9411805
# Name: Dan so tinh/thanh pho: , dtype: int64

# %%
print("Dan so ha noi:", population['Hà Nội'])
# Out:
# Dan so ha noi: 8330830

# %%
population['Đà Nẵng']
# Out:
# np.int64(1195490)

# %%
print(population[:3])  #In dân số 3 tinh dau tien
# Out:
# Hà Nội        8330830
# Quảng Ninh    1358085
# Nam Định      1836270
# Name: Dan so tinh/thanh pho: , dtype: int64

# %%
print(f"Mảng số liệu dân số", population.values)
# Out:
# Mảng số liệu dân số [8330830 1358085 1836270 1195490 9411805]

# %%
print(population[2:])
# Out:
# Nam Định          1836270
# Đà Nẵng           1195490
# TP.Hồ Chí Minh    9411805
# Name: Dan so tinh/thanh pho: , dtype: int64

# %%
print(population[1:3])
# Out:
# Quảng Ninh    1358085
# Nam Định      1836270
# Name: Dan so tinh/thanh pho: , dtype: int64

# %%
print(population.index)
# Out:
# Index(['Hà Nội', 'Quảng Ninh', 'Nam Định', 'Đà Nẵng', 'TP.Hồ Chí Minh'], dtype='object')

# %%
print(population.name)
# Out:
# Dan so tinh/thanh pho:

# %%
import matplotlib.pyplot as plt
population.plot(kind='bar', title='Dan so cac tinh thanh pho')
plt.ylabel('so nguoi')
plt.show()

# %%
import matplotlib.pyplot as plt
population.plot(kind='line', title='Dan so cac tinh thanh pho')
plt.ylabel('so nguoi')
plt.show()

# %% [markdown]
# VD4.3.3.1

# %%
import pandas as pd
area_dict={'Hà Nội':3358.9, 
            'Quảng Ninh':6177.7, 
            'Nam Định':1668.0, 
            'Đà Nẵng':1284.9, 
            'TP.Hồ Chí Minh':2061.0} 
area = pd.Series(area_dict) 
area
# Out:
# Hà Nội            3358.9
# Quảng Ninh        6177.7
# Nam Định          1668.0
# Đà Nẵng           1284.9
# TP.Hồ Chí Minh    2061.0
# dtype: float64

# %%
VietNam = pd.DataFrame({'Dân số':population, 'Diện tích':area}) 
VietNam
# Out:
#                  Dân số  Diện tích
# Hà Nội          8330830     3358.9
# Quảng Ninh      1358085     6177.7
# Nam Định        1836270     1668.0
# Đà Nẵng         1195490     1284.9
# TP.Hồ Chí Minh  9411805     2061.0
