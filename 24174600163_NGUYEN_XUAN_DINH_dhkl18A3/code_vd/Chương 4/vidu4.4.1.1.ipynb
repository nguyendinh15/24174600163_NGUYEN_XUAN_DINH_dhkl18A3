# %%
import pandas as pd 
data = pd.Series([1, 2, 3, 4], 
                index=['a','b','c','d']) 
data
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
'a' in data
# Out:
# True

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data.values
# Out:
# array([1, 2, 3, 4])

# %%
list(data.items())
# Out:
# [('a', 1), ('b', 2), ('c', 3), ('d', 4)]

# %%
data['e']=9.99 
data
# Out:
# a    1.00
# b    2.00
# c    3.00
# d    4.00
# e    9.99
# dtype: float64

# %%
data['a':'c']
# Out:
# a    1.0
# b    2.0
# c    3.0
# dtype: float64

# %%
data[0:2]
# Out:
# a    1.0
# b    2.0
# dtype: float64

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
list(data.items())
# Out:
# [('a', 1.0), ('b', 2.0), ('c', 3.0), ('d', 4.0), ('e', 9.99)]

# %% [markdown]
# VD4.4.1.5

# %%
indices_1=['b','d']       #explicit index 
selection_1=data[indices_1] 
selection_1
# Out:
# b    2.0
# d    4.0
# dtype: float64

# %%
indices_2=[1,3]           #implicit index 
selection_2=data[indices_2] 
selection_2
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16680\1873190884.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   selection_2=data[indices_2]
# b    2.0
# d    4.0
# dtype: float64
