# %%
import pandas as pd
import numpy as np

# Dữ liệu
data = {
    'A': [1.0, 2.0, np.nan, 4.0],
    'B': [np.nan, 6.0, 7.0, 8.0],
    'C': [9, 10, 11, 12]
}

# Tạo DataFrame
df = pd.DataFrame(data)

# In DataFrame
print(f"DataFrame gốc:\n", df)
# Out:
# DataFrame gốc:
#       A    B   C
# 0  1.0  NaN   9
# 1  2.0  6.0  10
# 2  NaN  7.0  11
# 3  4.0  8.0  12
