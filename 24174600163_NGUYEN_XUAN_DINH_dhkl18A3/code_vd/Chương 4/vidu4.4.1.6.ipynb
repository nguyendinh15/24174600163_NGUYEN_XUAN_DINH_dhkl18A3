# %%
import pandas as pd 
data = pd.Series(['a','b','c','d','e'],index=[1,3,5,6,7]) 
data
# Out:
# 1    a
# 3    b
# 5    c
# 6    d
# 7    e
# dtype: object

# %%
data[1]
# Out:
# 'a'

# %%
data[1:3]
# Out:
# 3    b
# 5    c
# dtype: object
