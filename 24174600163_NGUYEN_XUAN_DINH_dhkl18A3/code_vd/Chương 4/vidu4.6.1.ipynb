# %% [markdown]
# Ví dụ 4.6.1.1

# %%
import pandas as pd 

#Tuples đại diện cho tỉnh thành phố - Năm tương ứng 
index_tuples=[('Hà Nội',2015),('Hà Nội',2020), 
 ('Nam Định',2015),('Nam Định',2020), 
 ('Thanh Hóa',2015),('Thanh Hóa',2020), 
 ('Đà Nẵng',2015),('Đà Nẵng',2020), 
 ('Hồ Chí Minh',2015),('Hồ Chí Minh',2020)] 

data=[ 7216000, 8246540, 
       1850600, 1780330, 
       3514200, 3664940, 
       1028800, 1169480, 
       8146300, 9227600]

# %%
vn_pop = pd.Series(data, index=index_tuples)
print("Series sd index bang tuple")
vn_pop
# Out:
# Series sd index bang tuple
# (Hà Nội, 2015)         7216000
# (Hà Nội, 2020)         8246540
# (Nam Định, 2015)       1850600
# (Nam Định, 2020)       1780330
# (Thanh Hóa, 2015)      3514200
# (Thanh Hóa, 2020)      3664940
# (Đà Nẵng, 2015)        1028800
# (Đà Nẵng, 2020)        1169480
# (Hồ Chí Minh, 2015)    8146300
# (Hồ Chí Minh, 2020)    9227600
# dtype: int64

# %% [markdown]
# Ví dụ 4.6.1.2

# %%
vn_pop[('Hà Nội',2015):('Nam Định',2015)]
# Out:
# (Hà Nội, 2015)      7216000
# (Hà Nội, 2020)      8246540
# (Nam Định, 2015)    1850600
# dtype: int64

# %%
vn_pop.index
# Out:
# Index([     ('Hà Nội', 2015),      ('Hà Nội', 2020),    ('Nam Định', 2015),
#           ('Nam Định', 2020),   ('Thanh Hóa', 2015),   ('Thanh Hóa', 2020),
#            ('Đà Nẵng', 2015),     ('Đà Nẵng', 2020), ('Hồ Chí Minh', 2015),
#        ('Hồ Chí Minh', 2020)],
#       dtype='object')

# %% [markdown]
# Cách 1: Sử dụng vòng lặp

# %%
vn_pop[[i for i in vn_pop.index if i[1]==2020]]
# Out:
# (Hà Nội, 2020)         8246540
# (Nam Định, 2020)       1780330
# (Thanh Hóa, 2020)      3664940
# (Đà Nẵng, 2020)        1169480
# (Hồ Chí Minh, 2020)    9227600
# dtype: int64

# %% [markdown]
# Cách 2. Thực hiện chỉ mục phân cấp (Hierarchical Indexing) thông qua đối tượng đa chỉ mục/MultiIndex object.
# Tạo MultiIndex từ tuple.
# Ví dụ 4.6.1.4.

# %%
multi_idx=pd.MultiIndex.from_tuples(index_tuples, names=['Tỉnh/TP','Năm']) 
multi_idx
# Out:
# MultiIndex([(     'Hà Nội', 2015),
#             (     'Hà Nội', 2020),
#             (   'Nam Định', 2015),
#             (   'Nam Định', 2020),
#             (  'Thanh Hóa', 2015),
#             (  'Thanh Hóa', 2020),
#             (    'Đà Nẵng', 2015),
#             (    'Đà Nẵng', 2020),
#             ('Hồ Chí Minh', 2015),
#             ('Hồ Chí Minh', 2020)],
#            names=['Tỉnh/TP', 'Năm'])

# %% [markdown]
# Ví dụ 4.6.1.5

# %%
vn_pop_mul = vn_pop.reindex(multi_idx) 
vn_pop_mul
# Out:
# Tỉnh/TP      Năm
# Hà Nội       2015    7216000
#              2020    8246540
# Nam Định     2015    1850600
#              2020    1780330
# Thanh Hóa    2015    3514200
#              2020    3664940
# Đà Nẵng      2015    1028800
#              2020    1169480
# Hồ Chí Minh  2015    8146300
#              2020    9227600
# dtype: int64

# %% [markdown]
# series: 1 chieeuf
# dataFrame 2 chiue

# %%
type(vn_pop_mul)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Ví dụ 4.6.1.6

# %%
vn_pop_mul[:,2020]
# Out:
# Tỉnh/TP
# Hà Nội         8246540
# Nam Định       1780330
# Thanh Hóa      3664940
# Đà Nẵng        1169480
# Hồ Chí Minh    9227600
# dtype: int64

# %%
vn_pop_df = vn_pop_mul.unstack('Năm')
print("DataFrame dạng rộng: ")
display(vn_pop_df)
# Out:
# DataFrame dạng rộng:
# Năm             2015     2020
# Tỉnh/TP
# Hà Nội       7216000  8246540
# Hồ Chí Minh  8146300  9227600
# Nam Định     1850600  1780330
# Thanh Hóa    3514200  3664940
# Đà Nẵng      1028800  1169480

# %%
type(vn_pop_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print("DataFrame dạng dài: ")
display(vn_pop_df.stack())
# Out:
# DataFrame dạng dài:
# Tỉnh/TP      Năm
# Hà Nội       2015    7216000
#              2020    8246540
# Hồ Chí Minh  2015    8146300
#              2020    9227600
# Nam Định     2015    1850600
#              2020    1780330
# Thanh Hóa    2015    3514200
#              2020    3664940
# Đà Nẵng      2015    1028800
#              2020    1169480
# dtype: int64

# %%
type(vn_pop_df.stack())
# Out:
# pandas.core.series.Series

# %% [markdown]
# Ví dụ 4.6.1.8

# %%
vn_pop_df.stack()
# Out:
# Tỉnh/TP      Năm
# Hà Nội       2015    7216000
#              2020    8246540
# Hồ Chí Minh  2015    8146300
#              2020    9227600
# Nam Định     2015    1850600
#              2020    1780330
# Thanh Hóa    2015    3514200
#              2020    3664940
# Đà Nẵng      2015    1028800
#              2020    1169480
# dtype: int64

# %%
co_viec_2015 = [3752320, 1080750, 1512340, 512340, 4920000]
co_viec_2020 = [4042454, 1011049, 1600000, 600000, 5200000]

vn_pop_df_expanded = pd.DataFrame({
    ('Tổng dân số', 2015): vn_pop_df[2015],
    ('Tổng dân số', 2020): vn_pop_df[2020],
    ('Có việc', 2015): co_viec_2015,
    ('Có việc', 2020): co_viec_2020
}, index=vn_pop_df.index)

vn_pop_df_expanded.columns = pd.MultiIndex.from_tuples(vn_pop_df_expanded.columns, names=['Chi tiêu', 'Năm'])

vn_pop_df_expanded
# Out:
# Chi tiêu    Tổng dân số           Có việc
# Năm                2015     2020     2015     2020
# Tỉnh/TP
# Hà Nội          7216000  8246540  3752320  4042454
# Hồ Chí Minh     8146300  9227600  1080750  1011049
# Nam Định        1850600  1780330  1512340  1600000
# Thanh Hóa       3514200  3664940   512340   600000
# Đà Nẵng         1028800  1169480  4920000  5200000

# %%
f_co_viec = vn_pop_df_expanded['Có việc']/vn_pop_df_expanded['Tổng dân số']
f_co_viec
# Out:
# Năm              2015      2020
# Tỉnh/TP
# Hà Nội       0.520000  0.490200
# Hồ Chí Minh  0.132668  0.109568
# Nam Định     0.817216  0.898710
# Thanh Hóa    0.145791  0.163713
# Đà Nẵng      4.782271  4.446421

# %%
f_co_viec = vn_pop_df_expanded['Có việc']/vn_pop_df_expanded['Tổng dân số']
f_co_viec.unstack()
# Out:
# Năm   Tỉnh/TP
# 2015  Hà Nội         0.520000
#       Hồ Chí Minh    0.132668
#       Nam Định       0.817216
#       Thanh Hóa      0.145791
#       Đà Nẵng        4.782271
# 2020  Hà Nội         0.490200
#       Hồ Chí Minh    0.109568
#       Nam Định       0.898710
#       Thanh Hóa      0.163713
#       Đà Nẵng        4.446421
# dtype: float64

# %%
print(type(f_co_viec))
# Out:
# <class 'pandas.core.series.Series'>
