# %%
import numpy as np
import pandas as pd

# %%
s1 = pd.Series([2,4,6], index=['a','b','c'])
s1 = pd.Series([1,3,5], index=['b','c','d'])

# %%
s1
# Out:
# b    1
# c    3
# d    5
# dtype: int64

# %%
s3.add(s4,fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s3.add(s4,fill_value=0)
#
# NameError: name 's3' is not defined

# %%
import numpy as np

np.random.seed(0)
arr = np.random.randint(10, size=(3, 4))
arr
# Out:
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6]], dtype=int32)

# %%
arr[0]
# Out:
# array([5, 0, 3, 3], dtype=int32)

# %%
arr-arr[0]
# Out:
# array([[ 0,  0,  0,  0],
#        [ 2,  9,  0,  2],
#        [-3,  4,  4,  3]], dtype=int32)

# %%
df = pd.DataFrame(arr,columns=['P','Q','M','N'])
print("df:\n", df)
# Out:
# df:
#     P  Q  M  N
# 0  5  0  3  3
# 1  7  9  3  5
# 2  2  4  7  6

# %%
df.iloc[0]
# Out:
# P    5
# Q    0
# M    3
# N    3
# Name: 0, dtype: int32

# %%
df.iloc[0].index
# Out:
# Index(['P', 'Q', 'M', 'N'], dtype='object')

# %%
df.columns
# Out:
# Index(['P', 'Q', 'M', 'N'], dtype='object')

# %%
df.iloc[0].index==df.columns
# Out:
# array([ True,  True,  True,  True])

# %%
df.iloc[0].name
# Out:
# 0
