# %%
import pandas as pd 
data = pd.Series([1.0, 0.25, 6.0, 0.75]) 
data
# Out:
# 0    1.00
# 1    0.25
# 2    6.00
# 3    0.75
# dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data[0]
# Out:
# np.float64(1.0)

# %%
data[1]
# Out:
# np.float64(0.25)

# %%
print("Gia tri(values):", data.values)
# Out:
# Gia tri(values): [1.   0.25 6.   0.75]

# %%
print("Chi muc(index):", data.index)
# Out:
# Chi muc(index): RangeIndex(start=0, stop=4, step=1)
