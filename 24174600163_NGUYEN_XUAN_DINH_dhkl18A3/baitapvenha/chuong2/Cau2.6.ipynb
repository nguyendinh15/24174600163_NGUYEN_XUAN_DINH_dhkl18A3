# %%
import requests
import xml.etree.ElementTree as ET
import csv

# 1. Tải RSS và lưu file XML
url = "http://www.hindustantimes.com/rss/topnews/rssfeed.xml"
xml_file = "rss_feed.xml"
csv_file = "news.csv"

r = requests.get(url)
with open(xml_file, "wb") as f:
    f.write(r.content)

# 2. Phân tích cú pháp XML
tree = ET.parse(xml_file)
root = tree.getroot()

news_list = []
for item in root.findall(".//item"):
    news_list.append({
        "title": item.findtext("title"),
        "link": item.findtext("link"),
        "description": item.findtext("description")
    })

# 3. Lưu tin tức vào file CSV
with open(csv_file, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["title", "link", "description"])
    writer.writeheader()
    writer.writerows(news_list)

print("Đã tải và lưu RSS vào news.csv thành công!")
# Out:
# Đã tải và lưu RSS vào news.csv thành công!
