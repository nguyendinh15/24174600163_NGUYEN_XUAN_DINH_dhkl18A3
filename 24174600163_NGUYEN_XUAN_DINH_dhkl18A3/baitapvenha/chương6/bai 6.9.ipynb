# %%
import threading
import datetime
import time

def print_message(thread_name):
    for i in range(3):
        print(f"{thread_name}: Web {datetime.datetime.now().strftime('%b %d %H:%M:%S %Y')}")
        time.sleep(1)

    print(f"Exiting {thread_name}")

def main():
    print("Starting Main Thread")

    threads = []

    thread_names = ["Google", "Yahoo", "Facebook"]

    for name in thread_names:
        thread = threading.Thread(target=print_message, args=(name,))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

    print("Main Thread")
    print("Exiting")

main()
# Out:
# Starting Main Thread
# Google: Web Dec 22 20:16:44 2025
# Yahoo: Web Dec 22 20:16:44 2025
# Facebook: Web Dec 22 20:16:44 2025
# Google: Web Dec 22 20:16:45 2025
# Facebook: Web Dec 22 20:16:45 2025
# Yahoo: Web Dec 22 20:16:45 2025
# Google: Web Dec 22 20:16:46 2025Facebook: Web Dec 22 20:16:46 2025
#
# Yahoo: Web Dec 22 20:16:46 2025
# Exiting GoogleExiting Facebook
#
# Exiting Yahoo
# Main Thread
# Exiting
